# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data= pd.read_csv(r"C:\Users\Hp\Desktop\Prodigy Tasks\Task 1\pop\world_population_data.csv")

# %%
data
# Out:
#      rank cca3           country      continent  2023 population  \
# 0       1  IND             India           Asia       1428627663
# 1       2  CHN             China           Asia       1425671352
# 2       3  USA     United States  North America        339996563
# 3       4  IDN         Indonesia           Asia        277534122
# 4       5  PAK          Pakistan           Asia        240485658
# ..    ...  ...               ...            ...              ...
# 229   230  MSR        Montserrat  North America             4386
# 230   231  FLK  Falkland Islands  South America             3791
# 231   232  NIU              Niue        Oceania             1935
# 232   233  TKL           Tokelau        Oceania             1893
# 233   234  VAT      Vatican City         Europe              518
#
#      2022 population  2020 population  2015 population  2010 population  \
# 0         1417173173       1396387127       1322866505       1240613620
# ...

# %%
print(data.head())
# Out:
#    rank cca3        country      continent  2023 population  2022 population  \
# 0     1  IND          India           Asia       1428627663       1417173173
# 1     2  CHN          China           Asia       1425671352       1425887337
# 2     3  USA  United States  North America        339996563        338289857
# 3     4  IDN      Indonesia           Asia        277534122        275501339
# 4     5  PAK       Pakistan           Asia        240485658        235824862
#
#    2020 population  2015 population  2010 population  2000 population  \
# 0       1396387127       1322866505       1240613620       1059633675
# 1       1424929781       1393715448       1348191368       1264099069
# 2        335942003        324607776        311182845        282398554
# 3        271857970        259091970        244016173        214072421
# 4        227196741        210969298        194454498        154369924
#
#    1990 population  1980 population  1970 population  area (km²)  \
# ...

# %%
df=data.drop(columns=['rank','cca3','continent'])

# %%
df
# Out:
#               country  2023 population  2022 population  2020 population  \
# 0               India       1428627663       1417173173       1396387127
# 1               China       1425671352       1425887337       1424929781
# 2       United States        339996563        338289857        335942003
# 3           Indonesia        277534122        275501339        271857970
# 4            Pakistan        240485658        235824862        227196741
# ..                ...              ...              ...              ...
# 229        Montserrat             4386             4390             4500
# 230  Falkland Islands             3791             3780             3747
# 231              Niue             1935             1934             1942
# 232           Tokelau             1893             1871             1827
# 233      Vatican City              518              510              520
#
#      2015 population  2010 population  2000 population  1990 population  \
# ...

# %%
print(df.head())
# Out:
#          country  2023 population  2022 population  2020 population  \
# 0          India       1428627663       1417173173       1396387127
# 1          China       1425671352       1425887337       1424929781
# 2  United States        339996563        338289857        335942003
# 3      Indonesia        277534122        275501339        271857970
# 4       Pakistan        240485658        235824862        227196741
#
#    2015 population  2010 population  2000 population  1990 population  \
# 0       1322866505       1240613620       1059633675        870452165
# 1       1393715448       1348191368       1264099069       1153704252
# 2        324607776        311182845        282398554        248083732
# 3        259091970        244016173        214072421        182159874
# 4        210969298        194454498        154369924        115414069
#
#    1980 population  1970 population  area (km²)  density (km²) growth rate  \
# ...

# %%
df.columns
# Out:
# Index(['country', '2023 population', '2022 population', '2020 population',
#        '2015 population', '2010 population', '2000 population',
#        '1990 population', '1980 population', '1970 population', 'area (km²)',
#        'density (km²)', 'growth rate', 'world percentage'],
#       dtype='object')

# %%
columns=['2023 population', '2022 population', '2020 population',
       '2015 population', '2010 population', '2000 population',
       '1990 population', '1980 population', '1970 population', 'area (km²)',
       'density (km²)', 'growth rate', 'world percentage']

# %%
for i in columns:
     fig = plt.figure(figsize=(5,5))
     plt.hist(df[i],color='red',bins=10)
     plt.xlabel(i)
     plt.show()
